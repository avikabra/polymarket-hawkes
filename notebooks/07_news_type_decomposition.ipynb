# %% [markdown]
# # Notebook 07: News Type Decomposition (H3)
#
# Partitions test set by news_type × directional_impact. Expected: quantitative R² > high_attention R².
#
# **TODO:** Execute after running script 21.

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Load hypothesis test results and print H3 result
ht_path = Path("results/hypothesis_tests.json")
if ht_path.exists():
    with open(ht_path) as f:
        ht = json.load(f)
    h3 = ht.get('H3', {})
    print("H3 (quantitative > high_attention R²):")
    print(json.dumps(h3, indent=2))
else:
    print("results/hypothesis_tests.json not found — run script 21 first")

# %%
# TODO: Grouped bar chart — R²_OOS by news_type × category
# Expected columns in metrics_all: news_type (quantitative|high_attention|narrative),
# category, r2_oos, r2_ci_lo, r2_ci_hi
#
# metrics_path = Path("results/metrics_all.parquet")
# if metrics_path.exists():
#     df = pd.read_parquet(metrics_path)
#     decomp = df[df['architecture'] == 'transformer']
#     # plot grouped bars: x=news_type, hue=category
#     # ...
# pass
pass
